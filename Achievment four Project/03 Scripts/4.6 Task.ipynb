# %% [markdown]
# # Task 4.6

# %%
#Importing Libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# Import merged df

# %%
path = r'/Users/hannahstrassmann/Desktop/Achievment four Project/two Data'

# %%
# Import df_merged_orders_prior
df_merged_orders_prior = pd.read_pickle(os.path.join(path, 'Prepared Data', 'merged_orders_prior.pkl'))

# %%
df_merged_orders_prior.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_time  \
# 0   2539329        1             1                   2           8
# 1   2539329        1             1                   2           8
# 2   2539329        1             1                   2           8
# 3   2539329        1             1                   2           8
# 4   2539329        1             1                   2           8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered
# 0                     NaN         196                  1          0
# 1                     NaN       14084                  2          0
# 2                     NaN       12427                  3          0
# 3                     NaN       26088                  4          0
# 4                     NaN       26405                  5          0

# %%
#Checking shape of merged file
df_merged_orders_prior.shape
# Out:
# (32434489, 9)

# %% [markdown]
# 4. Shape is the same as exported df

# %% [markdown]
# Importing df_prods_checked

# %%
# Import df_prods_checked
df_prods_checked = pd.read_csv(os.path.join(path, 'Prepared Data', 'prods_checked.csv'), index_col = False)

# %%
df_prods_checked.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
df_prods_checked.shape
# Out:
# (49672, 5)

# %%
df_ords_prods_merge = df_merged_orders_prior.merge(df_prods_checked, on = ['product_id'], indicator = True)

# %% [markdown]
# Running megre with merge flag

# %%
# With merge flag
df_ords_prods_merge
# Out:
#           order_id  user_id  order_number  orders_day_of_week  order_time  \
# 0          2539329        1             1                   2           8
# 1          2539329        1             1                   2           8
# 2          2539329        1             1                   2           8
# 3          2539329        1             1                   2           8
# 4          2539329        1             1                   2           8
# ...            ...      ...           ...                 ...         ...
# 32404854   2977660   206209            13                   1          12
# 32404855   2977660   206209            13                   1          12
# 32404856   2977660   206209            13                   1          12
# 32404857   2977660   206209            13                   1          12
# 32404858   2977660   206209            13                   1          12
#
#           days_since_prior_order  product_id  add_to_cart_order  reordered  \
# ...

# %%
df_ords_prods_merge.shape
# Out:
# (32404859, 14)

# %%
df_ords_prods_merge['_merge'].value_counts()
# Out:
# _merge
# both          32404859
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %%
# Export new merged df as pickle
df_ords_prods_merge.to_pickle(os.path.join(path, 'Prepared Data', 'ords_prods_merge.pkl'))
