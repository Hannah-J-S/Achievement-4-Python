# %%
# Import Libraries
import pandas as pd
import numpy as np
import os

# %%
# Import path
path = r'/Users/hannahstrassmann/Desktop/Achievment four Project/two Data'

# %%
# Import datafram
df_ords_prods_merge_no_mean= pd.read_pickle(os.path.join(path, 'Prepared Data', 'ords_prods_merge_no_mean.pkl'))

# %%
df_ords_prods_merge_no_mean.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_time  \
# 0   2539329        1             1                   2           8
# 1   2539329        1             1                   2           8
# 2   2539329        1             1                   2           8
# 3   2539329        1             1                   2           8
# 4   2539329        1             1                   2           8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                     NaN       14084                  2          0
# 2                     NaN       12427                  3          0
# 3                     NaN       26088                  4          0
# 4                     NaN       26405                  5          0
#
#                               product_name  ...   busiest day  \
# 0                                     Soda  ...  regular busy
# ...

# %%
# Creating subset of df_ords_prods_merge (1000000 rows)
df = df_ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 25)

# %%
df.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_time  \
# 0   2539329        1             1                   2           8
# 1   2539329        1             1                   2           8
# 2   2539329        1             1                   2           8
# 3   2539329        1             1                   2           8
# 4   2539329        1             1                   2           8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                     NaN       14084                  2          0
# 2                     NaN       12427                  3          0
# 3                     NaN       26088                  4          0
# 4                     NaN       26405                  5          0
#
#                               product_name  ...   busiest day  \
# 0                                     Soda  ...  regular busy
# ...

# %%
df.groupby('product_name')

# %%
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                14.800024
# 2                17.091743
# 3                17.913544
# 4                17.893092
# 5                15.214270
# 6                15.382135
# 7                17.694027
# 8                16.458105
# 9                15.957363
# 10               20.091818
# 11               16.482026
# 12               15.615061
# 13               16.484023
# 14               17.524632
# 15               15.691875
# 16               18.014071
# 17               16.150593
# 18               19.602850
# 19               17.631340
# 20               17.138607
# 21               21.956893

# %%
df.groupby('department_id') ['order_number'].mean()
# Out:
# department_id
# 1     14.800024
# 2     17.091743
# 3     17.913544
# 4     17.893092
# 5     15.214270
# 6     15.382135
# 7     17.694027
# 8     16.458105
# 9     15.957363
# 10    20.091818
# 11    16.482026
# 12    15.615061
# 13    16.484023
# 14    17.524632
# 15    15.691875
# 16    18.014071
# 17    16.150593
# 18    19.602850
# 19    17.631340
# 20    17.138607
# 21    21.956893
# Name: order_number, dtype: float64

# %% [markdown]
# ###### df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})

# %%
df_ords_prods_merge ['max_order'] = df_ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)
# Out:
# /var/folders/pb/ntsf5rfn1rs9pmdn1yzhjxnw0000gn/T/ipykernel_46700/660364305.py:1: FutureWarning: The provided callable <function max at 0x106832f20> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   df_ords_prods_merge ['max_order'] = df_ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
df_ords_prods_merge.head(100)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_time  \
# 0    2539329        1             1                   2           8
# 1    2539329        1             1                   2           8
# 2    2539329        1             1                   2           8
# 3    2539329        1             1                   2           8
# 4    2539329        1             1                   2           8
# ..       ...      ...           ...                 ...         ...
# 95    738281        2             4                   2          10
# 96   1673511        2             5                   3          11
# 97   1673511        2             5                   3          11
# 98   1673511        2             5                   3          11
# 99   1673511        2             5                   3          11
#
#     days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                      NaN         196                  1          0
# ...

# %%
pd.options.display.max_rows = None

# %%
df_ords_prods_merge.head(10)
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_time  \
# 0   2539329        1             1                   2           8
# 1   2539329        1             1                   2           8
# 2   2539329        1             1                   2           8
# 3   2539329        1             1                   2           8
# 4   2539329        1             1                   2           8
# 5   2398795        1             2                   3           7
# 6   2398795        1             2                   3           7
# 7   2398795        1             2                   3           7
# 8   2398795        1             2                   3           7
# 9   2398795        1             2                   3           7
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                     NaN       14084                  2          0
# ...

# %%
df_ords_prods_merge.loc[df_ords_prods_merge['max_order']>40, 'loyalty_flag'] = 'loyal customer'
df_ords_prods_merge.loc[(df_ords_prods_merge['max_order']<= 40) & (df_ords_prods_merge['max_order'] >10), 'loyalty_flag'] = 'regular customer'
df_ords_prods_merge.loc[df_ords_prods_merge['max_order']<=10, 'loyalty_flag'] = 'new customer'

# %%
df_ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_time  \
# 0   2539329        1             1                   2           8
# 1   2539329        1             1                   2           8
# 2   2539329        1             1                   2           8
# 3   2539329        1             1                   2           8
# 4   2539329        1             1                   2           8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                     NaN       14084                  2          0
# 2                     NaN       12427                  3          0
# 3                     NaN       26088                  4          0
# 4                     NaN       26405                  5          0
#
#                               product_name  ...   busiest day  \
# 0                                     Soda  ...  regular busy
# ...

# %%
df_ords_prods_merge['loyalty_flag'].value_counts (dropna=False)
# Out:
# loyalty_flag
# regular customer    15876776
# loyal customer      10284093
# new customer         6243990
# Name: count, dtype: int64

# %%
df_ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0         1      new customer             1
# 1         1      new customer             1
# 2         1      new customer             1
# 3         1      new customer             1
# 4         1      new customer             1
# 5         1      new customer             2
# 6         1      new customer             2
# 7         1      new customer             2
# 8         1      new customer             2
# 9         1      new customer             2
# 10        1      new customer             2
# 11        1      new customer             3
# 12        1      new customer             3
# 13        1      new customer             3
# 14        1      new customer             3
# 15        1      new customer             3
# 16        1      new customer             4
# 17        1      new customer             4
# 18        1      new customer             4
# 19        1      new customer             4
# ...

# %%
df_ords_prods_merge.to_pickle(os.path.join(path,'Prepared Data', 'ords_prods_merge_no_mean.pkl'))
